# %% [markdown]
# # Propagule size tracking from RBG image
#
# ## 1. Documentation and Imports
#
#
# Created on 17-02-2021
#
# Author: Valentin Laplaud
#
# This code will load time series of propagules image in color, identify the propagule, and measure its size in time.

# %%
# plotting stuff
import matplotlib as mpl
import matplotlib.pyplot as plt

# numbers handling
import numpy as np
import pandas as pd

# images handling
from skimage import io
from skimage.filters import threshold_otsu, gaussian
from skimage.measure import label, regionprops_table
from skimage.util import invert
from skimage.morphology import binary_opening, binary_closing

# to hide known warnings
import warnings

# to remove and create folders
import os
import shutil

# %% [markdown]
# ## 2. Define analysis functions

# %% [markdown]
# ### 2.0 Create binary circle element for image processing

# %%
def create_circular_mask(h, w, center=None, radius=None):

    if center is None: # use the middle of the image
        center = (int(w/2), int(h/2))
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])

    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)

    mask = dist_from_center <= radius
    return mask

# %% [markdown]
# ### 2.1 Image Pre-processing
#
# GetHue : Computes Hue from RGB image. Also applies a gaussian blur for smoothness.
#
# Binarize : Threshold the Hue image using the Otsu threshold. Then opens the image using a circle of 30 µm.

# %%
def GetHue(RGBimg):
    
    warnings.filterwarnings("ignore") 
    
    RGBimg = gaussian(RGBimg,5)    

    HueImg = np.zeros(RGBimg.shape[0:2]) # initialize Hue img

    Maxes = RGBimg.argmax(axis=2)
    Mines = RGBimg.argmin(axis=2)

    # when red is max
    mask = Maxes == 0
    HueImg[mask] = (RGBimg[mask,1]-RGBimg[mask,2])/(RGBimg[mask,:].max(axis=1)-RGBimg[mask,:].min(axis=1))

    # when green is max
    mask = Maxes == 1
    HueImg[mask] = 2 + (RGBimg[mask,2]-RGBimg[mask,0])/(RGBimg[mask,:].max(axis=1)-RGBimg[mask,:].min(axis=1))

    # when blue is max
    mask = Maxes == 2
    HueImg[mask] = 4 + (RGBimg[mask,0]-RGBimg[mask,1])/(RGBimg[mask,:].max(axis=1)-RGBimg[mask,:].min(axis=1))


    # correct for nans
    HueImg[np.isnan(HueImg)] = 5

    HueImg = (HueImg/6)%1
      
    if DebugPlots:
                
        fig, (ax0, ax1) = plt.subplots(ncols=2)
        
        fig.suptitle('Debug plots for "GetHue" function :')
        ax0.imshow(RGBimg)
        ax0.set_title("RGB image")
        ax0.axis('off')
        ax1.imshow(HueImg, cmap='gray')
        ax1.set_title("Hue image")
        ax1.axis('off')
        
        plt.show()
        
        print('')
    
    return(HueImg)

def Binarize(Img, Scale):
    
    BWimg = invert(Img > threshold_otsu(Img)) # apply threshold 
    
    Size = np.round(30*Scale) # 30µm in pixels
    
    selem = create_circular_mask(Size,Size) # create circular element for opening

    FinalImg = binary_opening(BWimg,selem) # image opening
    
    if DebugPlots:        
       
        fig, (ax0, ax1, ax2) = plt.subplots(ncols=3)        
        fig.suptitle('Debug plots for "Binarize" function :')
        ax0.imshow(Img, cmap='gray')
        ax0.set_title("Original image")
        ax0.axis('off')
        ax1.imshow(BWimg, cmap='gray')
        ax1.set_title("Thresholded image")
        ax1.axis('off')
        ax2.imshow(FinalImg, cmap='gray')
        ax2.set_title("Opened image")
        ax2.axis('off')        
        
        plt.show()
        
        print('')
    
    return(FinalImg)

# %% [markdown]
# ### 2.3 Identify biggest object and returns its area
#
# Needs a binary image

# %%
def GetProps(BWimg,Scale):
    
    # extract properties from regions in the thresholded image
    label_img = label(BWimg)
    
    regions = regionprops_table(label_img, properties=('area','perimeter','bbox'))
    
    propstable = pd.DataFrame(regions) # convert into dataframe

    idx = np.argmax(propstable.area) # index reprensting the biggest object
                         
    pxArea = propstable.at[idx, 'area']

    Area = pxArea/Scale**2

    pxHeight = propstable.at[idx, 'bbox-2'] - propstable.at[idx, 'bbox-0']
    
    Height = pxHeight/Scale
                    
    return(Area, Height)

# %% [markdown]
# ## 3. Enter data and run

# %%
DebugPlots = False # Display intermediate plots along the way

# Paths to data
P = r'd:\Users\Valentin Laplaud\PostDoc\Data\Microscopy\2021.02.16'


# List of stacks to analyse
StackList = ['Puce_Propagule-03_Cropped.tif','Puce_Propagule-04_Cropped.tif','Puce_Propagule-06_Cropped.tif',
            'Puce_Propagule-07_Cropped.tif','Puce_Propagule-14_Cropped.tif','Puce_Propagule-16_Cropped.tif',
            'Puce_Propagule-19_Cropped.tif','Puce_Propagule-21_Cropped.tif','Puce_Propagule-22_Cropped.tif']


FPH = 2 # Framerate (frames per hour)
Scale = 2.5 # Spatial scale (px/µm)

Data = pd.DataFrame(data=None,columns=['Time (min)','Size (mm²)','Normalized Size','Height(µm)']) 




for s in StackList:
    
    print('Processing ' + s + ' :')    
    
    RGBstack = io.imread(P + '\\' + s) # get the tiff stack
    
    # Savefolders for Hue and Binary stacks
    if not os.path.exists(P + '\\' + s + '_Hue'):
        # shutil.rmtree(P + '\\' + s + '_Hue') # remove folder and contents
        os.mkdir(P + '\\' + s + '_Hue') # create folder
        isHue = False
    else:
        isHue = True
        
    if not os.path.exists(P + '\\' + s + '_Binarized'):
        # shutil.rmtree(P + '\\' + s + '_Binarized') # remove folder and contents
        os.mkdir(P + '\\' + s + '_Binarized') # create folder
        isBin = False
    else:
        isBin = True


    Area = np.zeros(len(RGBstack)) # initialize result vector
    Height = np.zeros(len(RGBstack)) # initialize result vector
    
    # compute Hue for each image
    for i in range(len(RGBstack)):
        
        if not isHue:
            print('Computing Hue for image ' + str(i+1) + '/' + str(len(RGBstack)) + '    ', end = '\r')

            HueImg = GetHue(gaussian(RGBstack[i],5)) 

            io.imsave(P + '\\' + s + '_Hue\\' + str(i) + '.tif', np.uint8(HueImg*255), plugin='tifffile')
            
        else:
            HueImg = io.imread(P + '\\' + s + '_Hue\\' + str(i) + '.tif')
    
        if not isBin:
            print('Binarization of image ' + str(i+1) + '/' + str(len(RGBstack)) + '      ', end = '\r')

            BinImg = Binarize(HueImg,Scale)    

            io.imsave(P + '\\' + s + '_Binarized\\' + str(i) + '.tif', np.uint8(BinImg*255), plugin='tifffile')
        else:
            BinImg = io.imread(P + '\\' + s + '_Binarized\\' + str(i) + '.tif')            
            
        print('Measuring area of propagule ' + str(i+1) + '/' + str(len(RGBstack)), end = '\r')
        
        Area[i], Height[i] = GetProps(BinImg,Scale)
            
    NormArea = Area/Area[0]
    
    print('Processing done for ' + str(len(RGBstack)) + '/' + str(len(RGBstack)) + ' images ')
    

    
     # creating dataframe for current stack
    DataCurr = pd.DataFrame(data=[[ np.arange(start=0, stop=len(RGBstack), step=1)/FPH*60,
                                   Area/1e6, NormArea,Height]],index = [s],
                                    columns=['Time (min)','Size (mm²)','Normalized Size','Height(µm)']) 
 
    Data = Data.append(DataCurr) # adding to global dataframe
    

    
# plot result

xTime = Data.at[s, 'Time (min)']
 
fig1 = plt.figure(dpi = 200)
fig1.suptitle('Size vs. time')
plt.xlabel('Time (min)')
plt.ylabel('Size (mm²)')

for s in StackList:
    
    idx700 = np.argwhere(Data.at[s, 'Height(µm)'] >700)[0][0]
    plt.plot(xTime,Data.at[s, 'Size (mm²)'],'-og',figure=fig1)
    plt.plot(xTime[idx700:],Data.at[s, 'Size (mm²)'][idx700:],'-or',figure=fig1)
    
fig1.savefig(P + '\\' + s + '_SizeTime.png')



fig2 = plt.figure(dpi = 200)
fig2.suptitle('Norm Size vs. time')
plt.xlabel('Time (min)')
plt.ylabel('Size (normalized)')


for s in StackList:
    

    plt.plot(xTime,Data.at[s, 'Normalized Size'],'-o',figure=fig2)
    
    

fig1.savefig(P + '\\' + s + '_NormSizeTime.png')

# %% [markdown]
# # Test Zone
